# %%
import pandas as pd
import quandl
 # SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()
quandl.ApiConfig.api_key = "wSFUoCTA1xVwxRGoYcem"

# %%
engine = create_engine('mysql://root:Batman!99@localhost:3306/stock_db')
data = quandl.get_table("ZACKS/MT", paginate=True)

# %%
data.head()
# Out:
#      m_ticker ticker        comp_name               comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC                Apple Inc.     NSDQ
# 1         AXP    AXP  AMER EXPRESS CO  American Express Company     NYSE
# 2          BA     BA        BOEING CO        The Boeing Company     NYSE
# 3         CTR    CAT  CATERPILLAR INC          Caterpillar Inc.     NYSE
# 4        CSCO   CSCO    CISCO SYSTEMS       Cisco Systems, Inc.     NSDQ
#
#      currency_code ticker_type active_ticker_flag  \
# None
# 0              USD           S                  Y
# 1              USD           S                  Y
# 2              USD           S                  Y
# 3              USD           S                  Y
# 4              USD           S                  Y
#
#                             comp_url  sic_4_code     ...      \
# None                                                 ...
# 0               http://www.apple.com        3571     ...
# ...

# %%
data.to_sql(name='company_info', con=engine, if_exists='replace')

# %%
data2 = quandl.get_table("ZACKS/CP", paginate=True)
data2.to_sql(name='company_addresses', con=engine, if_exists='replace')
