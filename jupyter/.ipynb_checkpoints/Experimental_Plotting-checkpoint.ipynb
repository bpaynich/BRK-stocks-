# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File to load
DIS_data_to_load = "../stock_csv/worldtradingdata-history-DIS.csv"

# Read CSV
DIS_data = pd.read_csv(DIS_data_to_load)

# Display preview
DIS_data.head()
# Out:
#          Date  Open  Close  High   Low  Volume
# 0  1972-06-01  1.92   1.92  1.92  1.92       0
# 1  1972-06-02  1.92   1.92  1.92  1.92       0
# 2  1972-06-05  1.92   1.92  1.92  1.92       0
# 3  1972-06-06  1.92   1.92  1.92  1.92       0
# 4  1972-06-07  1.93   1.93  1.93  1.93       0

# %%
# Create new column with ticker name
DIS_data["Ticker"] = "DIS"

DIS_data.head()
# Out:
#          Date  Open  Close  High   Low  Volume Ticker
# 0  1972-06-01  1.92   1.92  1.92  1.92       0    DIS
# 1  1972-06-02  1.92   1.92  1.92  1.92       0    DIS
# 2  1972-06-05  1.92   1.92  1.92  1.92       0    DIS
# 3  1972-06-06  1.92   1.92  1.92  1.92       0    DIS
# 4  1972-06-07  1.93   1.93  1.93  1.93       0    DIS

# %%
# Isolate date, open, and close columns from dataframe
date = DIS_data["Date"]
open = DIS_data["Open"]
close = DIS_data["Close"]

# Create the daily change by subtracting the opening price from the closing price
daily_change = close - open

# # Create a dataframe that displays all this information
# daily_change_df = pd.DataFrame({
#     "Date": date,
#     "Daily Change": daily_change
# })
# daily_change_df.head()

# %%
# Split the date column 
split_date = DIS_data["Date"].str.split("-", n = 1, expand = True) 

# Create a dataframe that displays all this information
daily_change_df = pd.DataFrame({
    "Year": split_date[0],
    "Month-Day": split_date[1],
    #"Day": split_date[2],
    "Daily Change": daily_change
})
daily_change_df.head()
# Out:
#    Year Month-Day  Daily Change
# 0  1972     06-01           0.0
# 1  1972     06-02           0.0
# 2  1972     06-05           0.0
# 3  1972     06-06           0.0
# 4  1972     06-07           0.0

# %%
# Find the average daily change for each date
date_change_avg = daily_change_df.groupby(["Month-Day"]).agg(
{
        "Daily Change":"mean"
    
})["Daily Change"]

# Change the series to a dataframe
date_change_avg_df = pd.DataFrame({
    "Average Daily Change": date_change_avg
})

plot = date_change_avg_df.plot.line(figsize=(20,3))

# %%
# Find the maximum average daily change
max_change = date_change_avg_df["Average Daily Change"].max()

max_change
# Out:
# 0.20399999999999968

# %%
# Find the corresponding date to this maximum average change
max_change_date = date_change_avg_df.loc[date_change_avg_df["Average Daily Change"] == max_change]
max_change_date
# Out:
#            Average Daily Change
# Month-Day
# 04-17                     0.204

# %%
last_year_df = daily_change_df.loc[daily_change_df['Year'] == "2018"]
last_year_df
# Out:
#        Year Month-Day  Daily Change
# 11505  2018     01-02          2.85
# 11506  2018     01-03          0.09
# 11507  2018     01-04         -0.72
# 11508  2018     01-05         -1.06
# 11509  2018     01-08         -0.87
# 11510  2018     01-09         -0.19
# 11511  2018     01-10         -0.49
# 11512  2018     01-11          0.74
# 11513  2018     01-12          1.15
# 11514  2018     01-16         -2.38
# 11515  2018     01-17          0.77
# 11516  2018     01-18         -1.32
# 11517  2018     01-19         -0.38
# 11518  2018     01-22          0.83
# 11519  2018     01-23          0.14
# 11520  2018     01-24         -0.46
# 11521  2018     01-25         -0.05
# 11522  2018     01-26          1.38
# 11523  2018     01-29         -0.56
# 11524  2018     01-30         -1.31
# 11525  2018     01-31         -1.41
# 11526  2018     02-01          1.87
# 11527  2018     02-02         -1.25
# 11528  2018     02-05         -2.40
# 11529  2018     02-06          3.29
# 11530  2018     02-07         -3.07
# 11531  2018     02-08         -4.12
# 11532  2018     02-09          0.54
# 11533  2018     02-12         -0.54
# 11534  2018     02-13          1.48
# ...     ...       ...           ...
# 11726  2018     11-15          0.62
# 11727  2018     11-16         -0.34
# 11728  2018     11-19         -0.58
# 11729  2018     11-20         -1.65
# 11730  2018     11-21          0.53
# 11731  2018     11-23         -0.16
# 11732  2018     11-26         -0.63
# 11733  2018     11-27          0.29
# 11734  2018     11-28          1.78
# 11735  2018     11-29          0.86
# 11736  2018     11-30         -1.35
# 11737  2018     12-03         -0.91
# 11738  2018     12-04         -2.75
# 11739  2018     12-06          2.27
# 11740  2018     12-07         -1.88
# 11741  2018     12-10         -0.13
# 11742  2018     12-11         -1.00
# 11743  2018     12-12         -0.79
# 11744  2018     12-13          0.52
# 11745  2018     12-14         -0.17
# 11746  2018     12-17         -1.67
# 11747  2018     12-18         -1.42
# 11748  2018     12-19         -0.78
# 11749  2018     12-20         -1.75
# 11750  2018     12-21         -2.25
# 11751  2018     12-24         -2.88
# 11752  2018     12-26          5.34
# 11753  2018     12-27          2.11
# 11754  2018     12-28          0.02
# 11755  2018     12-31          0.54
#
# [251 rows x 3 columns]

# %%
# Build a line chart that shows the daily change over time for DIS stock

plt.figure(figsize=(20,3))
plt.plot(last_year_df['Month-Day'], last_year_df['Daily Change'])
plt.show()
