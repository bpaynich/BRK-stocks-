# %%
import pandas as pd
import numpy as np
import glob
from sqlalchemy import create_engine
# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
engine = create_engine('mysql://root:June-17-94@localhost:3306/stock_db')

# %%
stock = 'INTC'

# %%
myQuery = f'select * from stock_db.master WHERE Name="{stock}"'
df = pd.read_sql_query(myQuery, engine)
df.head()
# Out:
#    index        Date  Open  Close  High   Low Volume  Name
# 0      0  1972-06-28  0.03   0.03  0.03  0.03      0  INTC
# 1      1  1972-06-29  0.03   0.03  0.03  0.03      0  INTC
# 2      2  1972-06-30  0.03   0.03  0.03  0.03      0  INTC
# 3      3  1972-07-03  0.03   0.03  0.03  0.03      0  INTC
# 4      4  1972-07-04  0.03   0.03  0.03  0.03      0  INTC

# %%
df1 = df.loc[df['index']%100==0, :]

# %%
df1.head(20)
# Out:
#       index        Date  Open  Close  High   Low Volume  Name
# 0         0  1972-06-28  0.03   0.03  0.03  0.03      0  INTC
# 100     100  1972-11-15  0.04   0.04  0.04  0.04      0  INTC
# 200     200  1973-04-06  0.04   0.04  0.04  0.04    600  INTC
# 300     300  1973-08-29  0.07   0.07  0.07  0.07  16000  INTC
# 400     400  1974-01-22  0.12   0.12  0.12  0.12  23300  INTC
# 500     500  1974-06-14  0.13   0.13  0.13  0.13  12800  INTC
# 600     600  1974-11-05  0.05   0.05  0.05  0.05  33900  INTC
# 700     700  1975-04-01  0.10   0.10  0.10  0.10  21300  INTC
# 800     800  1975-08-25  0.11   0.11  0.11  0.11  23300  INTC
# 900     900  1976-01-16  0.13   0.13  0.13  0.13  10900  INTC
# 1000   1000  1976-06-10  0.19   0.19  0.20  0.19  19200  INTC
# 1100   1100  1976-11-03  0.14   0.14  0.14  0.14  42000  INTC
# 1200   1200  1977-03-28  0.12   0.12  0.13  0.12  49500  INTC
# 1300   1300  1977-08-19  0.14   0.14  0.15  0.14   9600  INTC
# 1400   1400  1978-01-12  0.12   0.12  0.12  0.12  22300  INTC
# 1500   1500  1978-06-06  0.17   0.17  0.17  0.17  42100  INTC
# 1600   1600  1978-10-26  0.16   0.16  0.17  0.16  27000  INTC
# 1700   1700  1979-03-22  0.22   0.22  0.22  0.22  86900  INTC
# 1800   1800  1979-08-14  0.29   0.29  0.29  0.29  68000  INTC
# 1900   1900  1980-01-07  0.35   0.35  0.35  0.35  65100  INTC

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
date_list = df1['Date'].tolist()
close_list = df1['Close'].tolist()
# Out:
# C:\Users\roman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,5))
plt.title("Stock price over time")
plt.ylabel("Stock Price")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.plot(date_list, close_list)
plt.yticks()
plt.gcf().subplots_adjust(bottom=0.3)
#plt.autoscale()
plt.show()
plt.clf()

# %%
split_date= df["Date"].str.split("-", n = 2, expand = True) 

# Create a dataframe that displays all this information
df['Year'] = split_date[0]
df['Month'] = split_date[1]
df['Day'] = split_date[2]

# %%
df2 = df.loc[df['Year'] == '2018', :]
df2['Date'] = pd.to_datetime(df2['Date'])
df2.head()
# Out:
# C:\Users\roman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        index       Date   Open  Close   High    Low     Volume  Name  Year  \
# 11483  11483 2018-01-02  46.38  46.85  46.90  46.21   23370791  INTC  2018
# 11484  11484 2018-01-03  45.47  45.26  46.21  43.65  116478986  INTC  2018
# 11485  11485 2018-01-04  43.52  44.43  44.65  42.69   89209119  INTC  2018
# 11486  11486 2018-01-05  44.43  44.74  45.15  43.90   41824006  INTC  2018
# 11487  11487 2018-01-08  44.27  44.74  44.84  43.96   33733769  INTC  2018
#
#       Month Day
# 11483    01  02
# 11484    01  03
# 11485    01  04
# 11486    01  05
# 11487    01  08

# %%
year_date_list = df2['Date'].tolist()
year_price_list = df2['Close'].tolist()

# %%
plt.figure(figsize=(20,5))
plt.title("Stock price over 2018")
plt.ylabel("Stock Price")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.plot(year_date_list, year_price_list)
plt.yticks()
#plt.gcf().subplots_adjust(bottom=0.3)
#plt.autoscale()
plt.show()
plt.clf()

# %%
df['Volume'] = df['Volume'].astype(int)
df3 = df.groupby(df['Year']).mean()
df3['Year'] = df3.index
df3
# Out:
#         index       Open      Close       High        Low        Volume  Year
# Year
# 1972     65.5   0.037197   0.037197   0.037197   0.037197  0.000000e+00  1972
# 1973    258.5   0.060709   0.060709   0.062283   0.060709  1.150000e+04  1973
# 1974    512.0   0.085217   0.085217   0.087549   0.085217  2.932134e+04  1974
# 1975    764.0   0.112191   0.112191   0.114183   0.112191  3.062470e+04  1975
# 1976   1015.0   0.171434   0.171434   0.175418   0.171434  2.131713e+04  1976
# 1977   1266.5   0.132500   0.132500   0.137024   0.132500  2.481825e+04  1977
# 1978   1518.0   0.155179   0.155179   0.159880   0.155179  2.625896e+04  1978
# 1979   1770.0   0.265099   0.265099   0.270711   0.265099  4.325889e+04  1979
# 1980   2023.0   0.397194   0.397194   0.401186   0.397194  7.338577e+04  1980
# 1981   2275.5   0.338413   0.338413   0.341310   0.338413  1.209194e+05  1981
# 1982   2528.0   0.328893   0.328893   0.333874   0.328063  2.639696e+05  1982
# 1983   2781.0   0.681621   0.681621   0.692767   0.678893  3.945059e+05  1983
# 1984   3034.0   0.676759   0.676759   0.691462   0.673874  5.799747e+05  1984
# 1985   3287.0   0.567787   0.567787   0.577984   0.566047  6.046553e+05  1985
# 1986   3540.0   0.498735   0.498735   0.509091   0.488300  7.599976e+05  1986
# 1987   3793.0   0.876798   0.876798   0.895692   0.855494  1.617787e+06  1987
# 1988   4046.0   0.897273   0.897273   0.914664   0.880040  1.804447e+06  1988
# 1989   4298.5   0.927302   0.927302   0.941627   0.909881  1.525148e+06  1989
# 1990   4551.0   1.232055   1.232055   1.251542   1.208142  1.862670e+06  1990
# 1991   4804.0   1.448419   1.448419   1.473834   1.421028  2.185087e+06  1991
# 1992   5057.5   1.921181   1.921181   1.946969   1.887677  2.148416e+06  1992
# 1993   5311.0   3.615850   3.615850   3.672490   3.556087  4.149405e+06  1993
# 1994   5563.5   3.927659   3.927540   3.977619   3.866270  4.698954e+06  1994
# 1995   5816.0   6.883676   6.886285   6.983794   6.782372  1.462940e+06  1995
# 1996   6070.0  10.184667  10.198745  10.345412  10.029804  2.581642e+06  1996
# 1997   6324.0  19.884585  19.879802  20.242174  19.514308  1.441069e+07  1997
# 1998   6576.5  21.334524  21.354405  21.706071  20.964206  1.673707e+07  1998
# 1999   6828.5  34.282897  34.301349  34.953968  33.648810  2.173111e+07  1999
# 2000   7080.5  55.574048  55.527738  57.021548  54.239286  3.843691e+07  2000
# 2001   7330.5  29.164960  29.153629  29.953952  28.404395  5.267784e+07  2001
# 2002   7580.5  23.340595  23.295556  23.832381  22.785913  5.763630e+07  2002
# 2003   7832.5  23.576270  23.601746  23.925159  23.248135  5.725563e+07  2003
# 2004   8084.5  25.614048  25.562937  25.899008  25.289881  6.552924e+07  2004
# 2005   8336.5  24.929683  24.923532  25.170040  24.692302  5.876658e+07  2005
# 2006   8588.0  19.979044  19.955936  20.205538  19.759044  7.098263e+07  2006
# 2007   8839.0  23.392470  23.412948  23.662789  23.151434  6.520299e+07  2007
# 2008   9091.0  19.973557  19.960791  20.347905  19.597352  7.173365e+07  2008
# 2009   9343.5  17.094444  17.101627  17.356905  16.852183  6.434006e+07  2009
# 2010   9595.5  20.784603  20.770754  20.990952  20.538968  6.667750e+07  2010
# 2011   9847.5  22.025000  22.054365  22.275516  21.805675  6.141986e+07  2011
# 2012  10098.5  24.974160  24.974520  25.199280  24.748480  4.229823e+07  2012
# 2013  10349.5  23.044206  23.060198  23.241310  22.865556  3.911493e+07  2013
# 2014  10601.5  30.284921  30.327778  30.555357  30.049603  3.163601e+07  2014
# 2015  10853.5  32.147460  32.179127  32.498056  31.841389  3.029633e+07  2015
# 2016  11105.5  33.302897  33.329127  33.571627  33.031468  2.284215e+07  2016
# 2017  11357.0  37.772550  37.794661  38.042550  37.488765  2.390656e+07  2017
# 2018  11608.0  49.069482  49.055657  49.684622  48.442988  2.922509e+07  2018
# 2019  11762.5  50.455345  50.587759  51.015172  50.041207  2.404172e+07  2019

# %%
vol_date_list = df3['Year'].tolist()
vol_close_list = df3['Volume'].tolist()

# %%
plt.figure(figsize=(20,20))
plt.title("Yearly Average Volume")
plt.ylabel("Volume in shares")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain')
plt.bar(vol_date_list, vol_close_list)
plt.subplots_adjust(bottom=0.3)
plt.show()
