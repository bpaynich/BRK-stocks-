# %%
import pandas as pd
import glob
from sqlalchemy import create_engine
# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()

# %%
all_files = glob.glob("../stock_csv/*.csv")
engine = create_engine('mysql://root:****@localhost:3306/stock_db')

# %%
a = all_files[1]
apple = pd.read_csv(a)
apple['name'] = 'APPL'
apple.head(20)
# Out:
#           Date  Open  Close  High   Low   Volume  name
# 0   1970-01-02  1.25   1.22  1.25  1.22  1195200  APPL
# 1   1970-01-05  1.22   1.19  1.22  1.19   964800  APPL
# 2   1970-01-06  1.19   1.21  1.21  1.18  1036800  APPL
# 3   1970-01-07  1.21   1.21  1.22  1.20   331200  APPL
# 4   1970-01-08  1.21   1.22  1.23  1.21   460800  APPL
# 5   1970-01-09  1.22   1.22  1.24  1.22   748800  APPL
# 6   1970-01-12  1.22   1.20  1.22  1.20   864000  APPL
# 7   1970-01-13  1.20   1.21  1.22  1.20   849600  APPL
# 8   1970-01-14  1.21   1.23  1.23  1.21   619200  APPL
# 9   1970-01-15  1.23   1.23  1.23  1.23  1209600  APPL
# 10  1970-01-16  1.23   1.23  1.23  1.23   734400  APPL
# 11  1970-01-19  1.23   1.21  1.23  1.21  1180800  APPL
# 12  1970-01-20  1.21   1.21  1.21  1.19   763200  APPL
# 13  1970-01-21  1.21   1.22  1.22  1.21   878400  APPL
# 14  1970-01-22  1.22   1.22  1.22  1.21   360000  APPL
# 15  1970-01-23  1.22   1.22  1.23  1.21   979200  APPL
# ...

# %%
master = pd.DataFrame(columns=['Date','Open','Close','High', 'Low', 'Volume', 'Name'])
master
# Out:
# Empty DataFrame
# Columns: [Date, Open, Close, High, Low, Volume, Name]
# Index: []

# %%
for file in all_files:
    words = file.split('-')
    name = words[2].split('.')
    df = pd.read_csv(file)
    df['Name'] = name[0]
    master = master.append(df)

# %%
master
# Out:
#              Date   Open  Close   High    Low     Volume Name
# 0      2008-03-19  15.30  14.13  17.25  13.75  177121472    V
# 1      2008-03-20  14.60  16.09  16.25  14.38   49746236    V
# 2      2008-03-24  16.81  14.93  16.93  14.75   37423744    V
# 3      2008-03-25  15.15  15.81  16.06  14.96   21791298    V
# 4      2008-03-26  15.68  15.99  16.12  15.39   10784854    V
# 5      2008-03-27  16.01  15.73  16.18  15.66    9958761    V
# 6      2008-03-28  15.84  15.69  15.86  15.54    6174579    V
# 7      2008-03-31  15.65  15.59  15.87  15.51    5540062    V
# 8      2008-04-01  15.77  15.40  15.92  15.08   15105470    V
# 9      2008-04-02  15.43  15.58  15.58  15.13   10960140    V
# 10     2008-04-03  15.49  16.38  16.57  15.46   25203808    V
# 11     2008-04-04  16.23  16.12  16.33  15.94    9098811    V
# 12     2008-04-07  16.27  16.26  16.45  16.01    7078367    V
# 13     2008-04-08  16.20  17.02  17.06  16.20   13490957    V
# ...

# %%
master.to_sql(name='master', con=engine, if_exists='replace')
