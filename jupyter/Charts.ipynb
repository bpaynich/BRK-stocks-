# %%
import pandas as pd
import glob
from sqlalchemy import create_engine
# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
engine = create_engine('mysql://root:Batman!99@localhost:3306/stock_db')

# %%
myQuery = 'select * from stock_db.stock_quarter_close WHERE Name = "msft"'
df = pd.read_sql_query(myQuery, engine)
df.head()
# Out:
#    index        Date  Open  Close  High   Low  Volume  Name
# 0     11  1986-03-31  0.10   0.10  0.10  0.09   44700  MSFT
# 1     75  1986-06-30  0.11   0.11  0.11  0.10  216500  MSFT
# 2    139  1986-09-30  0.10   0.10  0.10  0.10   18000  MSFT
# 3    203  1986-12-31  0.17   0.17  0.17  0.17   81100  MSFT
# 4    265  1987-03-31  0.34   0.34  0.34  0.33  435200  MSFT

# %%
date_list = df['Date'].tolist()
close_list = df['Close'].tolist()
plt.figure(figsize=(20,10))
plt.title("Stock price over time")
plt.ylabel("Stock Price")
plt.xlabel("Date")
plt.xticks(rotation=90)
plt.plot(date_list, close_list)
plt.yticks()
plt.gcf().subplots_adjust(bottom=0.3)
#plt.autoscale()
plt.show()
plt.clf()

# %%
vol_date_list = df['Date'].tolist()
vol_close_list = df['Volume'].tolist()

# %%
        plt.figure(figsize=(20,20))
        plt.title("Volume over time")
        plt.ylabel("Volume in shares")
        plt.xlabel("Date")
        plt.xticks(rotation=90)
        plt.bar(vol_date_list, vol_close_list )
        plt.yticks()
        plt.gcf().subplots_adjust(bottom=0.3)
        #plt.autoscale()
        plt.show()
        #plt.clf()
