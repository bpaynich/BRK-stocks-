# %%
import pandas as pd
import glob
from sqlalchemy import create_engine
# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
engine = create_engine('mysql://root:Batman!99@localhost:3306/stock_db')

# %%
myQuery = 'select * from stock_db.stock_quarter_close WHERE Name = "XOM"'
df = pd.read_sql_query(myQuery, engine)
df.head()
# Out:
#    index        Date  Open  Close  High   Low Volume Name
# 0     21  1972-06-30  2.32   2.32  2.32  2.32      0  XOM
# 1    404  1973-12-31  2.95   2.95  2.95  2.94  26500  XOM
# 2    593  1974-09-30  1.84   1.84  1.85  1.83  63900  XOM
# 3    657  1974-12-31  2.02   2.02  2.02  1.97  30500  XOM
# 4    718  1975-03-31  2.31   2.31  2.34  2.31  36200  XOM

# %%
date_list = df['Date'].tolist()
close_list = df['Close'].tolist()
plt.figure(figsize=(20,10))
plt.title("Stock price over time")
plt.ylabel("Stock Price")
plt.xlabel("Date")
plt.xticks(rotation=90)
plt.plot(date_list, close_list)
plt.yticks()
plt.gcf().subplots_adjust(bottom=0.3)
#plt.autoscale()
plt.show()
plt.clf()

# %%
vol_date_list = df['Date'].tolist()
vol_close_list = df['Volume'].tolist()

# %%
        plt.figure(figsize=(20,20))
        plt.title("Volume over time")
        plt.ylabel("Volume in shares")
        plt.xlabel("Date")
        plt.xticks(rotation=90)
        plt.bar(vol_date_list, vol_close_list )
        plt.yticks()
        plt.gcf().subplots_adjust(bottom=0.3)
        #plt.autoscale()
        plt.show()
        #plt.clf()
