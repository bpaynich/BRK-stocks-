# %%
import pandas as pd
import quandl
 # SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()
quandl.ApiConfig.api_key = "wSFUoCTA1xVwxRGoYcem"

# %%
engine = create_engine('mysql://root:****@localhost:3306/stock_db')
data = quandl.get_table("ZACKS/MT", paginate=True)

# %%
data.head(30)
# Out:
#      m_ticker ticker        comp_name  \
# None
# 0        AAPL   AAPL        APPLE INC
# 1         AXP    AXP  AMER EXPRESS CO
# 2          BA     BA        BOEING CO
# 3         CTR    CAT  CATERPILLAR INC
# 4        CSCO   CSCO    CISCO SYSTEMS
# 5          SD    CVX     CHEVRON CORP
# 6         DIS    DIS      DISNEY WALT
# 7          GE     GE    GENL ELECTRIC
# 8         GS&     GS    GOLDMAN SACHS
# 9        HOMD     HD       HOME DEPOT
# 10        IBM    IBM    INTL BUS MACH
# 11        ITL   INTC       INTEL CORP
# 12        JNJ    JNJ  JOHNSON & JOHNS
# 13        CHL    JPM   JPMORGAN CHASE
# 14         KO     KO     COCA COLA CO
# 15        MCD    MCD   MCDONALDS CORP
# 16        MMM    MMM            3M CO
# 17        MRK    MRK   MERCK & CO INC
# 18       MSFT   MSFT   MICROSOFT CORP
# 19       NIKE    NKE       NIKE INC-B
# 20        PFE    PFE       PFIZER INC
# 21         PG     PG  PROCTER & GAMBL
# 22        SPM    TRV    TRAVELERS COS
# 23       UNIH    UNH  UNITEDHEALTH GP
# 24         UA    UTX   UTD TECHS CORP
# 25       VISA      V       VISA INC-A
# 26        BEL     VZ     VERIZON COMM
# 27        WMS    WMT      WALMART INC
# 28          J    XOM  EXXON MOBIL CRP
#
#                                       comp_name_2 exchange currency_code  \
# None
# 0                                      Apple Inc.     NSDQ           USD
# 1                        American Express Company     NYSE           USD
# 2                              The Boeing Company     NYSE           USD
# 3                                Caterpillar Inc.     NYSE           USD
# 4                             Cisco Systems, Inc.     NSDQ           USD
# 5                             Chevron Corporation     NYSE           USD
# 6                         The Walt Disney Company     NYSE           USD
# 7                        General Electric Company     NYSE           USD
# 8                   The Goldman Sachs Group, Inc.     NYSE           USD
# 9                            The Home Depot, Inc.     NYSE           USD
# 10    International Business Machines Corporation     NYSE           USD
# 11                              Intel Corporation     NSDQ           USD
# 12                              Johnson & Johnson     NYSE           USD
# 13                           JPMorgan Chase & Co.     NYSE           USD
# 14                        Coca-Cola Company (The)     NYSE           USD
# 15                         McDonald's Corporation     NYSE           USD
# 16                                     3M Company     NYSE           USD
# 17                              Merck & Co., Inc.     NYSE           USD
# 18                          Microsoft Corporation     NSDQ           USD
# 19                                     NIKE, Inc.     NYSE           USD
# 20                                    Pfizer Inc.     NYSE           USD
# 21                 Procter & Gamble Company (The)     NYSE           USD
# 22                  The Travelers Companies, Inc.     NYSE           USD
# 23                UnitedHealth Group Incorporated     NYSE           USD
# 24                United Technologies Corporation     NYSE           USD
# 25                                      Visa Inc.     NYSE           USD
# 26                    Verizon Communications Inc.     NYSE           USD
# 27                                   Walmart Inc.     NYSE           USD
# 28                        Exxon Mobil Corporation     NYSE           USD
#
#      ticker_type active_ticker_flag                             comp_url  \
# None
# 0              S                  Y                 http://www.apple.com
# 1              S                  Y       http://www.americanexpress.com
# 2              S                  Y                http://www.boeing.com
# 3              S                  Y           http://www.caterpillar.com
# 4              S                  Y                 http://www.cisco.com
# 5              S                  Y               http://www.chevron.com
# 6              S                  Y  http://www.thewaltdisneycompany.com
# 7              S                  Y                    http://www.ge.com
# 8              S                  Y          http://www.goldmansachs.com
# 9              S                  Y             http://www.homedepot.com
# 10             S                  Y                   http://www.ibm.com
# 11             S                  Y                 http://www.intel.com
# 12             S                  Y                   http://www.jnj.com
# 13             S                  Y         http://www.jpmorganchase.com
# 14             S                  Y      http://www.coca-colacompany.com
# 15             S                  Y        http://www.aboutmcdonalds.com
# 16             S                  Y                    http://www.3m.com
# 17             S                  Y                 http://www.merck.com
# 18             S                  Y             http://www.microsoft.com
# 19             S                  Y                  http://www.nike.com
# 20             S                  Y                http://www.pfizer.com
# 21             S                  Y                    https://us.pg.com
# 22             S                  Y             http://www.travelers.com
# 23             S                  Y     http://www.unitedhealthgroup.com
# 24             S                  Y                   http://www.utc.com
# 25             S                  Y                  http://usa.visa.com
# 26             S                  Y               http://www.verizon.com
# 27             S                  Y         http://www.stock.walmart.com
# 28             S                  Y      http://corporate.exxonmobil.com
#
#       sic_4_code     ...     per_end_month_nbr  mr_split_date mr_split_factor  \
# None                 ...
# 0           3571     ...                     9     2014-06-09             7.0
# 1           6199     ...                    12     2000-05-11             3.0
# 2           3721     ...                    12     1997-06-09             2.0
# 3           3531     ...                    12     2005-07-14             2.0
# 4           3576     ...                     7     2000-03-23             2.0
# 5           2911     ...                    12     2004-09-13             2.0
# 6           4841     ...                     9     1998-07-10             3.0
# 7           3600     ...                    12     2000-05-08             3.0
# 8           6211     ...                    12            NaT             NaN
# 9           5211     ...                     1     1999-12-31             1.5
# 10          3570     ...                    12     1999-05-27             2.0
# 11          3674     ...                    12     2000-07-31             2.0
# 12          2834     ...                    12     2001-06-13             2.0
# 13          6021     ...                    12     2000-06-12             1.5
# 14          2080     ...                    12     2012-08-13             2.0
# 15          5812     ...                    12     1999-03-08             2.0
# 16          3841     ...                    12     2003-09-30             2.0
# 17          2834     ...                    12     1999-02-17             2.0
# 18          7372     ...                     6     2003-02-18             2.0
# 19          3021     ...                     5     2015-12-24             2.0
# 20          2834     ...                    12     1999-07-01             3.0
# 21          2840     ...                     6     2004-06-21             2.0
# 22          6331     ...                    12     1998-05-12             2.0
# 23          6324     ...                    12     2005-05-31             2.0
# 24          3724     ...                    12     2005-06-13             2.0
# 25          7389     ...                     9     2015-03-19             4.0
# 26          4813     ...                    12     1998-06-30             2.0
# 27          5331     ...                     1     1999-04-20             2.0
# 28          2911     ...                    12     2001-07-19             2.0
#
#         comp_cik country_code   country_name comp_type  optionable_flag  \
# None
# 0     0000320193           US  UNITED STATES         1                Y
# 1     0000004962           US  UNITED STATES         2                Y
# 2     0000012927           US  UNITED STATES         1                Y
# 3     0000018230           US  UNITED STATES         1                Y
# 4     0000858877           US  UNITED STATES         1                Y
# 5     0000093410           US  UNITED STATES         1                Y
# 6     0001001039           US  UNITED STATES         1                Y
# 7     0000040545           US  UNITED STATES         1                Y
# 8     0000886982           US  UNITED STATES        10                Y
# 9     0000354950           US  UNITED STATES         1                Y
# 10    0000051143           US  UNITED STATES         1                Y
# 11    0000050863           US  UNITED STATES         1                Y
# 12    0000200406           US  UNITED STATES         1                Y
# 13    0000019617           US  UNITED STATES         2                Y
# 14    0000021344           US  UNITED STATES         1                Y
# 15    0000063908           US  UNITED STATES         1                Y
# 16    0000066740           US  UNITED STATES         1                Y
# 17    0000310158           US  UNITED STATES         1                Y
# 18    0000789019           US  UNITED STATES         1                Y
# 19    0000320187           US  UNITED STATES         1                Y
# 20    0000078003           US  UNITED STATES         1                Y
# 21    0000080424           US  UNITED STATES         1                Y
# 22    0000086312           US  UNITED STATES         7                Y
# 23    0000731766           US  UNITED STATES         1                Y
# 24    0000101829           US  UNITED STATES         1                Y
# 25    0001403161           US  UNITED STATES         1                Y
# 26    0000732712           US  UNITED STATES         6                Y
# 27    0000104169           US  UNITED STATES         1                Y
# 28    0000034088           US  UNITED STATES         1                Y
#
#      sp500_member_flag  asset_type
# None
# 0                    Y         COM
# 1                    Y         COM
# 2                    Y         COM
# 3                    Y         COM
# 4                    Y         COM
# 5                    Y         COM
# 6                    Y         COM
# 7                    Y         COM
# 8                    Y         COM
# 9                    Y         COM
# 10                   Y         COM
# 11                   Y         COM
# 12                   Y         COM
# 13                   Y         COM
# 14                   Y         COM
# 15                   Y         COM
# 16                   Y         COM
# 17                   Y         COM
# 18                   Y         COM
# 19                   Y         COM
# 20                   Y         COM
# 21                   Y         COM
# 22                   Y         COM
# 23                   Y         COM
# 24                   Y         COM
# 25                   Y         COM
# 26                   Y         COM
# 27                   Y         COM
# 28                   Y         COM
#
# [29 rows x 27 columns]

# %%
data.to_sql(name='company_info', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2220         try:
# -> 2221             return fn()
#    2222         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     413         if not self._use_threadlocal:
# --> 414             return _ConnectionFairy._checkout(self)
#     415
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     810         if not fairy:
# --> 811             fairy = _ConnectionRecord.checkout(pool)
#     812
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     542     def checkout(cls, pool):
# --> 543         rec = pool._do_get()
#     544         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1238                 with util.safe_reraise():
# -> 1239                     self._dec_overflow()
#    1240         else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1235             try:
# -> 1236                 return self._create_connection()
#    1237             except:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     360
# --> 361         return _ConnectionRecord(self)
#     362
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     487         if connect:
# --> 488             self.__connect(first_connect_check=True)
#     489         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     689             self.starttime = time.time()
# --> 690             connection = pool._invoke_creator(self)
#     691             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1049, "Unknown database 'stock_db'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-4-fec8f8169275> in <module>()
# ----> 1 data.to_sql(name='company_info', con=engine, if_exists='replace')
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1124                          if_exists=if_exists, index_label=index_label,
#    1125                          schema=schema, dtype=dtype)
# -> 1126         table.create()
#    1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in create(self)
#     559
#     560     def create(self):
# --> 561         if self.exists():
#     562             if self.if_exists == 'fail':
#     563                 raise ValueError("Table '%s' already exists." % self.name)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in exists(self)
#     547
#     548     def exists(self):
# --> 549         return self.pd_sql.has_table(self.name, self.schema)
#     550
#     551     def sql_schema(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    1152             self.connectable.dialect.has_table,
#    1153             name,
# -> 1154             schema or self.meta.schema,
#    1155         )
#    1156
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in run_callable(self, callable_, *args, **kwargs)
#    2115
#    2116         """
# -> 2117         with self.contextual_connect() as conn:
#    2118             return conn.run_callable(callable_, *args, **kwargs)
#    2119
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2183         return self._connection_cls(
#    2184             self,
# -> 2185             self._wrap_pool_connect(self.pool.connect, None),
#    2186             close_with_result=close_with_result,
#    2187             **kwargs
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2223             if connection is None:
#    2224                 Connection._handle_dbapi_exception_noconnection(
# -> 2225                     e, dialect, self
#    2226                 )
#    2227             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1520             util.raise_from_cause(newraise, exc_info)
#    1521         elif should_wrap:
# -> 1522             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1523         else:
#    1524             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2219         dialect = self.dialect
#    2220         try:
# -> 2221             return fn()
#    2222         except dialect.dbapi.Error as e:
#    2223             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     412         """
#     413         if not self._use_threadlocal:
# --> 414             return _ConnectionFairy._checkout(self)
#     415
#     416         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     809     def _checkout(cls, pool, threadconns=None, fairy=None):
#     810         if not fairy:
# --> 811             fairy = _ConnectionRecord.checkout(pool)
#     812
#     813             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     541     @classmethod
#     542     def checkout(cls, pool):
# --> 543         rec = pool._do_get()
#     544         try:
#     545             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1237             except:
#    1238                 with util.safe_reraise():
# -> 1239                     self._dec_overflow()
#    1240         else:
#    1241             return self._do_get()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             self._exc_info = None  # remove potential circular references
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#      69             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     275         if value.__traceback__ is not tb:
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#     279
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1234         if self._inc_overflow():
#    1235             try:
# -> 1236                 return self._create_connection()
#    1237             except:
#    1238                 with util.safe_reraise():
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     359         """Called by subclasses to create a new ConnectionRecord."""
#     360
# --> 361         return _ConnectionRecord(self)
#     362
#     363     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     486         self.__pool = pool
#     487         if connect:
# --> 488             self.__connect(first_connect_check=True)
#     489         self.finalize_callback = deque()
#     490
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     688         try:
#     689             self.starttime = time.time()
# --> 690             connection = pool._invoke_creator(self)
#     691             pool.logger.debug("Created new connection %r", connection)
#     692             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     435
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#     439     def create_connect_args(self, url):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     859
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#     863         # if authentication method isn't accepted the first byte
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1049, "Unknown database 'stock_db'") (Background on this error at: http://sqlalche.me/e/2j85)

# %%
data2 = quandl.get_table("ZACKS/CP", paginate=True)
data2.to_sql(name='company_addresses', con=engine, if_exists='replace')
